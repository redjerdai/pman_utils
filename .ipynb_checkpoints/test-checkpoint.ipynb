# %%
#

# %%
import numpy
import pandas

# %%
from pman_utils.portfolio_skeleton import PortfolioSleketon

# %%
M = 100
time_axis = pandas.date_range(start='2020-01-01', end='2021-01-01', freq='D')
N = time_axis.shape[0]
N
# Out:
# 367

# %%
tickers = ['A{0}'.format(j) for j in numpy.arange(M)]
real = pandas.DataFrame(data=numpy.concatenate([numpy.arange(start=1000, step=10, stop=1000 + 10 * N).reshape(-1, 1) for _ in numpy.arange(M)], axis=1), index=time_axis, columns=tickers)
real
# Out:
#               A0    A1    A2    A3    A4    A5    A6    A7    A8    A9  ...  \
# 2020-01-01  1000  1000  1000  1000  1000  1000  1000  1000  1000  1000  ...
# 2020-01-02  1010  1010  1010  1010  1010  1010  1010  1010  1010  1010  ...
# 2020-01-03  1020  1020  1020  1020  1020  1020  1020  1020  1020  1020  ...
# 2020-01-04  1030  1030  1030  1030  1030  1030  1030  1030  1030  1030  ...
# 2020-01-05  1040  1040  1040  1040  1040  1040  1040  1040  1040  1040  ...
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2020-12-28  4620  4620  4620  4620  4620  4620  4620  4620  4620  4620  ...
# 2020-12-29  4630  4630  4630  4630  4630  4630  4630  4630  4630  4630  ...
# 2020-12-30  4640  4640  4640  4640  4640  4640  4640  4640  4640  4640  ...
# 2020-12-31  4650  4650  4650  4650  4650  4650  4650  4650  4650  4650  ...
# 2021-01-01  4660  4660  4660  4660  4660  4660  4660  4660  4660  4660  ...
#
#              A90   A91   A92   A93   A94   A95   A96   A97   A98   A99
# 2020-01-01  1000  1000  1000  1000  1000  1000  1000  1000  1000  1000
# 2020-01-02  1010  1010  1010  1010  1010  1010  1010  1010  1010  1010
# 2020-01-03  1020  1020  1020  1020  1020  1020  1020  1020  1020  1020
# 2020-01-04  1030  1030  1030  1030  1030  1030  1030  1030  1030  1030
# 2020-01-05  1040  1040  1040  1040  1040  1040  1040  1040  1040  1040
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2020-12-28  4620  4620  4620  4620  4620  4620  4620  4620  4620  4620
# 2020-12-29  4630  4630  4630  4630  4630  4630  4630  4630  4630  4630
# 2020-12-30  4640  4640  4640  4640  4640  4640  4640  4640  4640  4640
# 2020-12-31  4650  4650  4650  4650  4650  4650  4650  4650  4650  4650
# 2021-01-01  4660  4660  4660  4660  4660  4660  4660  4660  4660  4660
#
# [367 rows x 100 columns]

# %%
predicted_data = real.values + numpy.random.normal(loc=0.0, scale=1.0, size=(N, M))
predicted = pandas.DataFrame(data=predicted_data, index=time_axis, columns=tickers)
predicted
# Out:
#                      A0           A1           A2           A3           A4  \
# 2020-01-01  1001.012136  1000.845246  1001.156582   999.277642  1000.801280
# 2020-01-02  1009.702900  1009.585471  1009.560393  1009.499316  1009.366770
# 2020-01-03  1019.492161  1018.336961  1020.198894  1018.580396  1020.819846
# 2020-01-04  1030.101638  1029.036969  1030.674346  1029.825816  1029.782958
# 2020-01-05  1039.943369  1039.621504  1038.393602  1040.228034  1038.920445
# ...                 ...          ...          ...          ...          ...
# 2020-12-28  4618.455699  4620.778479  4619.972183  4620.402568  4619.321058
# 2020-12-29  4630.892996  4631.050954  4628.403247  4629.862630  4629.878352
lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     616         try:
# --> 617             return self._convert_to_indexer(key, axis=0, is_setter=True)
#     618         except TypeError as e:
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, key, axis, is_setter)
#    1197                 # When setting, missing keys are not allowed, even with .loc:
# -> 1198                 return self._get_listlike_indexer(key, axis, raise_missing=True)[1]
#    1199         else:
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1248         if ax.is_unique and not getattr(ax, "is_overlapping", False):
# -> 1249             indexer = ax.get_indexer_for(keyarr)
#    1250             keyarr = ax.reindex(keyarr)[0]
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4706         if self.is_unique:
# -> 4707             return self.get_indexer(target, **kwargs)
#    4708         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     368             # checks/conversions/roundings are delegated to general method
# --> 369             return super().get_indexer(target, method=method, tolerance=tolerance)
#     370
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2974             target = target.astype(object)
# -> 2975             return this.get_indexer(
#    2976                 target, method=method, limit=limit, tolerance=tolerance
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2999
# -> 3000             indexer = self._engine.get_indexer(target._get_engine_target())
#    3001
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1664     def __hash__(self):
# -> 1665         raise TypeError(
#    1666             f"{repr(type(self).__name__)} objects are mutable, "
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# The above exception was the direct cause of the following exception:
#
# IndexingError                             Traceback (most recent call last)
# <ipython-input-9-0640b1feeae6> in <module>
# ----> 1 dec = ptf.get_all()
#       2 dec
#
# C:\Sygm\RAMP\IP-02\OSTRTA\pman_utils\pman_utils\portfolio_skeleton.py in get_all(self)
#      68
#      69     def get_all(self):
# ---> 70         return self.get_decisions(), self.get_take_profits(), self.get_stop_losses()
#
# C:\Sygm\RAMP\IP-02\OSTRTA\pman_utils\pman_utils\portfolio_skeleton.py in get_take_profits(self)
#      64         for col in profits_taken.columns.values:
#      65             mask = self.decisions[col] != 0
# ---> 66             profits_taken.loc[mask, col] = self.predicted.loc[mask, col]
#      67         return profits_taken
#      68
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     664         else:
#     665             key = com.apply_if_callable(key, self.obj)
# --> 666         indexer = self._get_setitem_indexer(key)
#     667         self._has_valid_setitem_indexer(key)
#     668
#
# E:\venv\pman_utils\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     623             elif "unhashable type" in str(e):
#     624                 raise
# --> 625             raise IndexingError(key) from e
#     626
#     627     def _ensure_listlike_indexer(self, key, axis=None):
#
# IndexingError: (2020-01-01    False
# 2020-01-02    False
# 2020-01-03    False
# 2020-01-04    False
# 2020-01-05    False
#               ...
# 2020-12-28    False
# 2020-12-29    False
# 2020-12-30    False
# 2020-12-31    False
# 2021-01-01    False
# Freq: D, Name: A0, Length: 367, dtype: bool, 'A0')
